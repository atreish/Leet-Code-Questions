# %% [markdown]
# 206. Reverse Linked List
#
# Given the head of a singly linked list, reverse the list, and return the reversed list.
#
# Example 1:
#
# ![Screen%20Shot%202023-01-26%20at%2011.53.26%20AM.png](attachment:Screen%20Shot%202023-01-26%20at%2011.53.26%20AM.png)

# %%
def reverseList(self, head):
    prev = None
    curr = head

    while curr:
        next = curr.next
        curr.next = prev
        prev = curr
        curr = next
    
    return prev
